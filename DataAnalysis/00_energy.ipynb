# %%
import pandas as pd

# %%
df = pd.read_csv("./Data_energy/한국에너지공단_신재생에너지센터 관련 사이트 정보_20200205.csv",encoding = "cp949")
df.head(10)
# Out:
#    번호  구분  국가구분    국가                        주소(URL)                  영문기관명  \
# 0   5   1     1    한국          http://www.moe.go.kr/  Ministry of Education
# 1   8   1     1  대한민국  http://www.greengrowth.go.kr/       GreenGrowthKorea
# 2   9   2     1  대한민국        https://www.kimm.re.kr/                   KIMM
# 3  10   1     1  대한민국           http://www.moe.go.kr  Ministry of Education
# 4  11   2     1  대한민국        http://www.kigam.re.kr/                  KIGAM
# 5  12   1     1  대한민국         http://www.mafra.go.kr                  MAFRA
# 6  15   2     1  대한민국        http://www.stepi.re.kr/                  STEPI
# 7  16   2     1  대한민국          http://www.keei.re.kr                   KEEI
# 8  17   2     1  대한민국           http://www.kei.re.kr                    KEI
# 9  18   2     1  대한민국         http://www.kier.re.kr/                   KIER
#
#       등록아이디                                                 내용  파일경로  \
# ...
